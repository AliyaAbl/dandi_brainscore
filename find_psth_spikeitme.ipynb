# %%
import numpy as np
import io
import pandas as pd

path = 'Pipeline Monkey Schedule.xlsx'
data = pd.read_excel(path, sheet_name='Pico')
# Out:
# Running cells with 'dandibs' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n dandibs ipykernel --update-deps --force-reinstall'

# %%
import os
import fnmatch

def find_files_with_extension(root_dir, extension):
    file_paths = []
    for foldername, subfolders, filenames in os.walk(root_dir):
        for filename in fnmatch.filter(filenames, f'*.{extension}'):
            file_paths.append(os.path.join(foldername, filename))
    return file_paths

# Example usage:
parent_directory = '/path/to/parent_directory'
extension = 'h5'
h5_files = find_files_with_extension(parent_directory, extension)

# List of paths to all .h5 files in the subdirectories
print(h5_files)
# Out:
#        Fixation Training             Unnamed: 1       Unnamed: 2  Unnamed: 3  \
# 0                   Date                Stimuli  Fixation Window  Visual Deg
# 1              1/31/2022                  Oasis               15           8
# 2               2/1/2022            Normalizers               15           8
# 3               2/2/2022            Normalizers                5           8
# 4               2/3/2022                  Oasis                5           8
# ..                   ...                    ...              ...         ...
# 465                  NaN  robustness_guy_d1_v35                2           8
# 466  2023-09-14 00:00:00            Normalizers                2           8
# 467                  NaN  robustness_guy_d1_v36                2           8
# 468  2023-09-19 00:00:00            Normalizers                2           8
# 469                  NaN  robustness_guy_d0_v37                2           8
#
#       Unnamed: 4 Unnamed: 5         Unnamed: 6      Unnamed: 7  \
# 0    ON/OFF (ms)       Reps  Stimuli per Trial  Images*/Videos
# 1        100/100          1                  2             930
# 2        100/100         80                  2              26
# 3        100/100         87                2/3              26
# 4        100/100          4                3/4             930
# ..           ...        ...                ...             ...
# 465      100/100         65                  8             330
# 466      100/100         20                  8              86
# 467      100/100         65                  8             330
# 468      100/100         20                  8              86
# 469      100/100          2                  8           11000
#
#               Unnamed: 8   Unnamed: 9       Unnamed: 10         Unnamed: 11  \
# 0    Total images/Videos  Reward (ms)  Total Water (ml)        aIT Pedestal
# 1                  ~1500  150 (Rig 3)               NaN                 NaN
# 2                   2080          100               NaN                 NaN
# 3                   2262        80/90               220                 NaN
# 4                   3986        65/75               220                 NaN
# ..                   ...          ...               ...                 ...
# 465                21450        60-75               NaN                 NaN
# 466                 1720           50               450  adaptorAIT.v2.2023
# 467                21450        60-75               NaN                 NaN
# 468                 1720           50               450  adaptorAIT.v2.2023
# 469                22000        60-75               NaN                 NaN
#
#             Unnamed: 12      Unnamed: 13  \
# 0          pIT Pedestal      Referencing
# 1                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN
# ..                  ...              ...
# 465                 NaN              NaN
# 466  adaptorPIT.v2.2023  Referenced to G
# 467                 NaN              NaN
# 468  adaptorPIT.v2.2023  Referenced to G
# 469                 NaN              NaN
#
#                                            Unnamed: 14  \
# 0                                                Notes
# 1    About 700 succesful trials, 2 and 3 stimuli_pe...
# 2                                 in lab for 1.5 hours
# 3    in lab for 1.5 hours, was able to do 3 stimuli...
# 4                        in lab for 1 hour, great day!
# ..                                                 ...
# 465                                                NaN
# 466               Gamma correction off, room light on.
# 467                                                NaN
# 468               Gamma correction off, room light on.
# 469                                                NaN
#
#     Began in-cage fixation training on 12/27/2021  \
# 0                             2021-12-01 00:00:00
# 1                                            Date
# 2                             2021-12-27 00:00:00
# 3                             2021-12-28 00:00:00
# 4                             2021-12-29 00:00:00
# ..                                            ...
# 465                                           NaN
# 466                                           NaN
# 467                                           NaN
# 468                                           NaN
# 469                                           NaN
#
#                                            Unnamed: 16
# 0                                                  NaN
# 1                                                Notes
# 2    Began iPad fixation training: 1:15-2:15pm atta...
# 3    Second day: 12-1:30pm, had about 50 successful...
# 4    11-2pm, over 500 trials. Upped reward to 200ms...
# ..                                                 ...
# 465                                                NaN
# 466                                                NaN
# 467                                                NaN
# 468                                                NaN
# 469                                                NaN
#
# [470 rows x 17 columns]
