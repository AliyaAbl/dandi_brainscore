# %%
import numpy as np
import io
import pandas as pd
import os
import fnmatch
import shutil
import re

os.chdir('/om/user/aliya277')
path = 'dandi_brainscore/Pipeline Monkey Schedule.xlsx'
pico_data = pd.read_excel(path, sheet_name='Pico')
new_header = pico_data.iloc[0]  #grab the first row for the header
pico_data = pico_data[1:]       #take the data less the header row
pico_data.columns = new_header  #set the header row as the df header
pico_data = pico_data.fillna('empty')

# %%
import shutil
shutil.copytree('/om/user/aliya277/inventory', '/braintree/home/aliya277/dandi_brainscore/inventory')
# Out:
# '/braintree/home/aliya277/dandi_brainscore/inventory'

# %%
def find_files_with_extension(root_dir, extension):
    file_paths = []
    for foldername, subfolders, filenames in os.walk(root_dir):
        for filename in fnmatch.filter(filenames, f'*.{extension}'):
            file_paths.append(os.path.join(foldername, filename))
    return file_paths

# Example usage:
parent_directory = '/braintree/data2/active/users/sgouldin/projects'
extension = 'h5'
h5_files = find_files_with_extension(parent_directory, extension)

# List of paths to all .h5 files in the subdirectories
# h5_parent = []
# for path in h5_files:
#     h5_parent.append(os.path.join(*path.split('/')[0:10]))

# %%
def find_directories_with_name(root_dir, directory_name):
    directory_paths = []
    for foldername, subfolders, _ in os.walk(root_dir):
        if directory_name in subfolders:
            directory_paths.append(os.path.join(foldername, directory_name))
    return directory_paths

# Example usage:
parent_directory = '/braintree/data2/active/users/sgouldin/projects'
target_directory_name = 'spikeTime'
spikeTime_directories = find_directories_with_name(parent_directory, target_directory_name)

# List of paths to directories with the name 'spikeTime'
# spike_parent = []
# for path in spike_parent:
#     spike_parent.append(os.path.join(*path.split('/')[0:10]))

# %%
# Convert the lists to sets
spikeTime_set = set(spike_parent)
other_set = set(h5_parent)

# Find the directories that are unique to each set
unique_to_spikeTime = spikeTime_set - other_set
unique_to_other = other_set - spikeTime_set

# Check if the sets are different
if len(unique_to_spikeTime) > 0 or len(unique_to_other) > 0:
    print("The sets are different.")
else:
    print("The sets are the same.")

# Print the unique directories
print("Directories unique to 'spikeTime':")
print(unique_to_spikeTime)

print("Directories unique to 'h5':")
print(unique_to_other)
# Out:
# The sets are different.
# Directories unique to 'spikeTime':
# {'braintree/data2/active/users/sgouldin/projects/muri1320/monkeys/pico', 'braintree/data2/active/users/sgouldin/projects/robustness_guy_d0_v25/intanproc/pico_robustness_d0_v25_230612_133119'}
# Directories unique to 'h5':
# {'braintree/data2/active/users/sgouldin/projects/robustness_guy_d0_v7_chong_dryrun/monkeys/pico', 'braintree/data2/active/users/sgouldin/projects/robustness_guy_d0_v25/h5/pico.rsvp.robustness_guy_d0_v25.experiment_psth_raw.h5'}

# %%
pd.set_option("display.max_rows", 10)
pico_data#.iloc[[243]].Stimuli #= 'facesMSFDE'
# Out:
# 0                   Date                Stimuli Fixation Window Visual Deg  \
# 1              1/31/2022                  Oasis              15          8
# 2               2/1/2022            Normalizers              15          8
# 3               2/2/2022            Normalizers               5          8
# 4               2/3/2022                  Oasis               5          8
# 5               2/4/2022                  Oasis               5          8
# ..                   ...                    ...             ...        ...
# 465                empty  robustness_guy_d1_v35               2          8
# 466  2023-09-14 00:00:00            Normalizers               2          8
# 467                empty  robustness_guy_d1_v36               2          8
# 468  2023-09-19 00:00:00            Normalizers               2          8
# 469                empty  robustness_guy_d0_v37               2          8
#
# 0   ON/OFF (ms) Reps Stimuli per Trial Images*/Videos Total images/Videos  \
# 1       100/100    1                 2            930               ~1500
# 2       100/100   80                 2             26                2080
# 3       100/100   87               2/3             26                2262
# 4       100/100    4               3/4            930                3986
# 5       100/100    5                 4            930                4650
# ..          ...  ...               ...            ...                 ...
# 465     100/100   65                 8            330               21450
# 466     100/100   20                 8             86                1720
# 467     100/100   65                 8            330               21450
# 468     100/100   20                 8             86                1720
# 469     100/100    2                 8          11000               22000
#
# 0    Reward (ms) Total Water (ml)        aIT Pedestal        pIT Pedestal  \
# 1    150 (Rig 3)            empty               empty               empty
# 2            100            empty               empty               empty
# 3          80/90              220               empty               empty
# 4          65/75              220               empty               empty
# 5       70/75/80              200               empty               empty
# ..           ...              ...                 ...                 ...
# 465        60-75            empty               empty               empty
# 466           50              450  adaptorAIT.v2.2023  adaptorPIT.v2.2023
# 467        60-75            empty               empty               empty
# 468           50              450  adaptorAIT.v2.2023  adaptorPIT.v2.2023
# 469        60-75            empty               empty               empty
#
# 0        Referencing                                              Notes  \
# 1              empty  About 700 succesful trials, 2 and 3 stimuli_pe...
# 2              empty                               in lab for 1.5 hours
# 3              empty  in lab for 1.5 hours, was able to do 3 stimuli...
# 4              empty                      in lab for 1 hour, great day!
# 5              empty  able to calibrate at window size 2, was frustr...
# ..               ...                                                ...
# 465            empty                                              empty
# 466  Referenced to G               Gamma correction off, room light on.
# 467            empty                                              empty
# 468  Referenced to G               Gamma correction off, room light on.
# 469            empty                                              empty
#
# 0    2021-12-01 00:00:00                                                NaN
# 1                   Date                                              Notes
# 2    2021-12-27 00:00:00  Began iPad fixation training: 1:15-2:15pm atta...
# 3    2021-12-28 00:00:00  Second day: 12-1:30pm, had about 50 successful...
# 4    2021-12-29 00:00:00  11-2pm, over 500 trials. Upped reward to 200ms...
# 5    2021-12-30 00:00:00  Had to stop in-cage training and WR because th...
# ..                   ...                                                ...
# 465                empty                                              empty
# 466                empty                                              empty
# 467                empty                                              empty
# 468                empty                                              empty
# 469                empty                                              empty
#
# [469 rows x 17 columns]

# %%
def get_date(date):
    """
    Get the Dates from the Excel file.
    """

    try:
        dates = date.split('/')
        if len(dates[-1])>2:year = dates[-1]
        else: year=f'20{dates[-1]}'
        if len(dates[0])>1: month = dates[0]
        else: month = f'0{dates[0]}'
        if len(dates[1])>1:day=dates[1]
        else:day=f'0{dates[1]}'
        

    except:
        try:
            dates = str(date).split()[0].split('-')
            if len(dates)==3:
                year=dates[0]
                month=dates[1]
                if len(dates[2])>1:day=dates[2]
                else:day=f'0{dates[2]}'
            else:
                pass
        except:
            pass

    try: return day, month, year
    except: return 0,0,0
    
############### Create Storage Dir and Load Excel File ########################
###############################################################################
   
storage_dir = '/braintree/home/aliya277/dandi_brainscore/inventory'
try: os.mkdir(storage_dir)
except: pass
os.chdir('/om/user/aliya277')
path = 'dandi_brainscore/Pipeline Monkey Schedule New.xlsx'
data = pd.read_excel(path, sheet_name='pico')
new_header = data.iloc[0]  
data = data[1:]       
data.columns = new_header  
data = data.fillna('empty')  


def find_files_with_pattern(root_dir, pattern):
    """
    Find Associated .h5 File for each SpikeTime Folder.
    """
    return [os.path.join(foldername, filename) for foldername, subfolders, filenames in os.walk(root_dir) for filename in filenames if filename.startswith(pattern) and filename.endswith('.h5')]


for spike in (spikeTime_directories):

    ############### Get Recording Info from FileName ##############################
    ###############################################################################
    ind = spike.split('/').index('intanproc')
    SubjectName     = spike.split('/')[ind-1]
    ImageSetName_v1 = spike.split('/')[ind-3]
    Date            = re.findall('..',spike.split('/')[ind+1].split('_')[-2])
    year            = f'20{Date[0]}'
    month           = Date[1]
    day             = Date[2]
    SessionTime     = spike.split('/')[ind+1].split('_')[-1]

    
    if SubjectName == 'pico':


        ############### Filter by Date in FileName and ExcelDate ##########################
        ###############################################################################
        for date,index in zip(data['Date'], range(1,len(data))):
            exl_day, exl_month, exl_year = get_date(date)

            if exl_day+exl_month+exl_year == day+month+year:


                ############### Filter by FileName and ExcelStimulus ##########################
                ###############################################################################
                list = [data['Stimuli'][index]]
                for i in range(1,10):
                    try:
                        if data['Date'][index+i] == 'empty':
                            list.append(data['Stimuli'][index+i])
                            i+=1
                        else:
                            break
                    except:break
                found_item = False

                for item, i in zip(list, range(len(list))): 
                    if item.lower() in ImageSetName_v1:
                        ImageSetName = data['Stimuli'][index+i]
                        StimOnnOff   = data['ON/OFF (ms)'][index+i]
                        found_item = True

                if found_item == False:
                    for item, i in zip(list, range(len(list))):
                        spike_new = ImageSetName_v1.lower().replace('-', '_').split('_')
                        item_new = item.lower().replace('-', '_').split('_') 

                        if set(item_new).intersection(set(spike_new)) == set(item_new) or set(spike_new).intersection(set(item_new)) == set(spike_new):
                            ImageSetName = data['Stimuli'][index+i]
                            StimOnnOff   = data['ON/OFF (ms)'][index+i]
                            found_item = True
                
                ############### Create Standartized Directory Name ############################
                ###############################################################################
                if found_item == True:
                    SessionDate = f'{year}{month}{day}'
                    if ImageSetName == 'Normalizers':
                        directory = f'norm_FOSS.sub_{SubjectName}.{SessionDate}_{SessionTime}.proc'
                    elif ImageSetName == 'Normalizers-HVM':
                        directory = f'norm_HVM.sub_{SubjectName}.{SessionDate}_{SessionTime}.proc'
                    else: 
                        directory = f'exp_{ImageSetName}.sub_{SubjectName}.{SessionDate}_{SessionTime}.proc'

                    try: os.mkdir(os.path.join(storage_dir, directory))
                    except: pass


                    ############### Copy Files in Respective Inventory Directory ##################
                    ###############################################################################
                    # matching_h5files = find_files_with_pattern(os.path.join('/', *spike.split('/')[0:10]), f'{Date[0]}{Date[1]}{Date[2]}')
                    
                    # shutil.copytree(spike, os.path.join(storage_dir, directory, 'SpikeTimes'))
                    # if matching_h5files:
                    #     for files in matching_h5files:
                    #         try: os.mkdir(os.path.join(storage_dir, directory, 'h5Files'))
                    #         except: pass
                    #         shutil.copy2(files, os.path.join(storage_dir, directory, 'h5Files', files.split('/')[-1]))

                    ############### Create .txt File with Relevant Info for NWB ###################
                    ###############################################################################
                    with open(os.path.join(storage_dir, directory,'NWBInfo.txt'), 'w') as f:
                        f.write(str(StimOnnOff )+','+ spike)
                        print(spike)

                    
                else:
                    # print('Wrong Names: ', month, day, year, list, '\t', spike.split('/')[ind-3], index)
                    pass
# Out:
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_220615_113442/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_220616_111545/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_220901_144739/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_220902_145351/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_220907_142157/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_220929_170635/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_220930_151743/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230303_152601/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230214_134820/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230215_145155/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230216_145353/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230217_140904/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230221_124922/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230222_143642/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230223_132511/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230224_142014/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230227_133424/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230301_140442/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230302_133030/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230428_111937/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230328_145456/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230505_130540/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230508_120630/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230509_112900/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230510_111142/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230510_125550/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230530_130736/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230518_103908/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230517_115439/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230516_120137/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230515_133554/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230511_120927/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230601_124810/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230531_134209/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230605_122450/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230606_134244/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230607_103909/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230125_144402/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230127_160227/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230612_131205/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230126_150653/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230608_150826/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230609_133109/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230613_124343/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230616_100142/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230621_140747/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230622_130058/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230623_131505/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230626_131126/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230627_112925/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230628_124854/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230629_132813/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230630_135832/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230705_122755/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230706_120215/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230707_140510/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230710_131212/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230711_142158/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230712_134744/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230713_141950/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230714_135126/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230717_155454/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230719_121341/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230721_122001/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230724_104204/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230725_113504/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230726_135354/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230727_153732/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230728_164343/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230729_152949/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230730_134454/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230731_104339/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230801_142733/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230808_132257/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230809_120658/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230804_152622/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230828_113012/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230802_124516/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230803_105856/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230814_122811/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230815_110014/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230816_101041/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230817_141050/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230818_095451/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230821_120107/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230822_153931/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230823_124104/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230825_100059/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230830_110931/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230905_094523/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230901_115230/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230906_093230/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers/monkeys/pico/intanproc/pico_normalizers_230831_121100/spikeTime
# /braintree/data2/active/users/sgouldin/projects/muri1320/monkeys/pico/intanproc/pico_muri1320_220615_115139/spikeTime
# /braintree/data2/active/users/sgouldin/projects/ko_context_size/monkeys/pico/intanproc/pico_ko_context_size_220930_153358/spikeTime
# /braintree/data2/active/users/sgouldin/projects/muri1320-2023-v1/monkeys/pico/intanproc/pico_muri1320-2023-v1_230127_161915/spikeTime
# /braintree/data2/active/users/sgouldin/projects/muri1320-2023-v1/monkeys/pico/intanproc/pico_muri1320-2023-v1_230127_172414/spikeTime
# /braintree/data2/active/users/sgouldin/projects/muri1320-2023-v1/monkeys/pico/intanproc/pico_muri1320-2023-v1_230130_142333/spikeTime
# /braintree/data2/active/users/sgouldin/projects/muri1320-2023-v1/monkeys/pico/intanproc/pico_muri1320-2023-v1_230130_144347/spikeTime
# /braintree/data2/active/users/sgouldin/projects/muri1320-2023-v1/monkeys/pico/intanproc/pico_muri1320-2023-v1_230131_152020/spikeTime
# /braintree/data2/active/users/sgouldin/projects/muri1320-2023-v1/monkeys/pico/intanproc/pico_muri1320-2023-v1_230131_183129/spikeTime
# /braintree/data2/active/users/sgouldin/projects/muri1320-2023-v1/monkeys/pico/intanproc/pico_muri1320-2023-v1_230201_135241/spikeTime
# /braintree/data2/active/users/sgouldin/projects/muri1320-2023-v1/monkeys/pico/intanproc/pico_muri1320-2023-v1_230201_152725/spikeTime
# /braintree/data2/active/users/sgouldin/projects/HVM-var6-subset-2023/monkeys/pico/intanproc/pico_HVM-var6-subset-2023_230303_180103/spikeTime
# /braintree/data2/active/users/sgouldin/projects/images_in_context/monkeys/pico/intanproc/ko-pico-rsvpShapeTxt_230324_121431/spikeTime
# /braintree/data2/active/users/sgouldin/projects/muri1320-2023-v0/monkeys/pico/intanproc/pico_muri1320-2023-v0_230124_122922/spikeTime
# /braintree/data2/active/users/sgouldin/projects/muri1320-2023-v0/monkeys/pico/intanproc/pico_muri1320-2023-v0_230126_152420/spikeTime
# /braintree/data2/active/users/sgouldin/projects/muri1320-2023-v0/monkeys/pico/intanproc/pico_muri1320-2023-v0_230124_140420/spikeTime
# /braintree/data2/active/users/sgouldin/projects/muri1320-2023-v0/monkeys/pico/intanproc/pico_muri1320-2023-v0_230125_150432/spikeTime
# /braintree/data2/active/users/sgouldin/projects/muri1320-2023-v0/monkeys/pico/intanproc/pico_muri1320-2023-v0_230125_161525/spikeTime
# /braintree/data2/active/users/sgouldin/projects/domain-transfer-2023/monkeys/pico/intanproc/pico_domain-transfer-2023_230214_140610/spikeTime
# /braintree/data2/active/users/sgouldin/projects/domain-transfer-2023/monkeys/pico/intanproc/pico_domain-transfer-2023_230215_161322/spikeTime
# /braintree/data2/active/users/sgouldin/projects/domain-transfer-2023/monkeys/pico/intanproc/pico_domain-transfer-2023_230216_150919/spikeTime
# /braintree/data2/active/users/sgouldin/projects/domain-transfer-2023/monkeys/pico/intanproc/pico_domain-transfer-2023_230217_153101/spikeTime
# /braintree/data2/active/users/sgouldin/projects/domain-transfer-2023/monkeys/pico/intanproc/pico_domain-transfer-2023_230221_130510/spikeTime
# /braintree/data2/active/users/sgouldin/projects/domain-transfer-2023/monkeys/pico/intanproc/pico_domain-transfer-2023_230222_153723/spikeTime
# /braintree/data2/active/users/sgouldin/projects/domain-transfer-2023/monkeys/pico/intanproc/pico_domain-transfer-2023_230223_134049/spikeTime
# /braintree/data2/active/users/sgouldin/projects/domain-transfer-2023/monkeys/pico/intanproc/pico_domain-transfer-2023_230224_154435/spikeTime
# /braintree/data2/active/users/sgouldin/projects/domain-transfer-2023/monkeys/pico/intanproc/pico_domain-transfer-2023_230227_135006/spikeTime
# /braintree/data2/active/users/sgouldin/projects/domain-transfer-2023/monkeys/pico/intanproc/pico_domain-transfer-2023_230301_153048/spikeTime
# /braintree/data2/active/users/sgouldin/projects/domain-transfer-2023/monkeys/pico/intanproc/pico_domain-transfer-2023_230302_134615/spikeTime
# /braintree/data2/active/users/sgouldin/projects/domain-transfer-2023/monkeys/pico/intanproc/pico_domain-transfer-2023_230303_162745/spikeTime
# /braintree/data2/active/users/sgouldin/projects/HVM-var6-2023/monkeys/pico/intanproc/pico_HVM-var6-2023_230214_154007/spikeTime
# /braintree/data2/active/users/sgouldin/projects/HVM-var6-2023/monkeys/pico/intanproc/pico_HVM-var6-2023_230215_150717/spikeTime
# /braintree/data2/active/users/sgouldin/projects/HVM-var6-2023/monkeys/pico/intanproc/pico_HVM-var6-2023_230216_163217/spikeTime
# /braintree/data2/active/users/sgouldin/projects/HVM-var6-2023/monkeys/pico/intanproc/pico_HVM-var6-2023_230217_142420/spikeTime
# /braintree/data2/active/users/sgouldin/projects/HVM-var6-2023/monkeys/pico/intanproc/pico_HVM-var6-2023_230221_142542/spikeTime
# /braintree/data2/active/users/sgouldin/projects/HVM-var6-2023/monkeys/pico/intanproc/pico_HVM-var6-2023_230222_145258/spikeTime
# /braintree/data2/active/users/sgouldin/projects/HVM-var6-2023/monkeys/pico/intanproc/pico_HVM-var6-2023_230223_150327/spikeTime
# /braintree/data2/active/users/sgouldin/projects/HVM-var6-2023/monkeys/pico/intanproc/pico_HVM-var6-2023_230224_143600/spikeTime
# /braintree/data2/active/users/sgouldin/projects/HVM-var6-2023/monkeys/pico/intanproc/pico_HVM-var6-2023_230227_151407/spikeTime
# /braintree/data2/active/users/sgouldin/projects/HVM-var6-2023/monkeys/pico/intanproc/pico_HVM-var6-2023_230301_142202/spikeTime
# /braintree/data2/active/users/sgouldin/projects/HVM-var6-2023/monkeys/pico/intanproc/pico_HVM-var6-2023_230302_151005/spikeTime
# /braintree/data2/active/users/sgouldin/projects/HVM-var6-2023/monkeys/pico/intanproc/pico_HVM-var6-2023_230303_154230/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers-HVM/monkeys/pico/intanproc/pico_normalizers-HVM_230404_142414/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers-HVM/monkeys/pico/intanproc/pico_normalizers-HVM_230405_112307/spikeTime
# /braintree/data2/active/users/sgouldin/projects/normalizers-HVM/monkeys/pico/intanproc/pico_normalizers-HVM_230406_114701/spikeTime
# /braintree/data2/active/users/sgouldin/projects/facesMSFDE/monkeys/pico/intanproc/ko-pico-facesMSFDE_230327_134955/spikeTime
# /braintree/data2/active/users/sgouldin/projects/facescrub-small/monkeys/pico/intanproc/pico_facescrub-small_230329_130459/spikeTime
# /braintree/data2/active/users/sgouldin/projects/facescrub-small/monkeys/pico/intanproc/pico_facescrub-small_230330_124309/spikeTime
# /braintree/data2/active/users/sgouldin/projects/facescrub-small/monkeys/pico/intanproc/pico_facescrub-small_230331_135015/spikeTime
# /braintree/data2/active/users/sgouldin/projects/shinecut/monkeys/pico/intanproc/pico_shinecut_230406_144835/spikeTime
# /braintree/data2/active/users/sgouldin/projects/images_in_context2/monkeys/pico/intanproc/pico_images_in_context2_230407_113258/spikeTime
# /braintree/data2/active/users/sgouldin/projects/objectsize/monkeys/pico/intanproc/pico_objectsize_230505_132032/spikeTime
# /braintree/data2/active/users/sgouldin/projects/novel500/monkeys/pico/intanproc/pico_novel500_230530_132227/spikeTime
# /braintree/data2/active/users/sgouldin/projects/images_in_context3/monkeys/pico/intanproc/pico_images_in_context3_230531_135649/spikeTime
# /braintree/data2/active/users/sgouldin/projects/motionset1/monkeys/pico/intanproc/pico_motionset1_230601_130223/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d0_v24/monkeys/pico/intanproc/pico_robustness_d0_v24_230606_140254/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d0_v24/monkeys/pico/intanproc/pico_robustness_d0_v24_230607_105626/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d0_v24/monkeys/pico/intanproc/pico_robustness_d0_v24_230605_130743/spikeTime
# /braintree/data2/active/users/sgouldin/projects/Alireza_paradigm1/monkeys/pico/intanproc/pico_paradigm1_230616_103724/spikeTime
# /braintree/data2/active/users/sgouldin/projects/Alireza_paradigm2/monkeys/pico/intanproc/pico_paradigm2_230616_113851/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d0_v26/monkeys/pico/intanproc/pico_robustness_d0_v26_230621_142345/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d1_v26/monkeys/pico/intanproc/pico_robustness_d1_v26_230622_131538/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d1_v27/monkeys/pico/intanproc/pico_robustness_d1_v27_230623_133026/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d0_v30/monkeys/pico/intanproc/pico_robustness_guy_d0_v30_230706_122443/spikeTime
# /braintree/data2/active/users/sgouldin/projects/moca/monkeys/pico/intanproc/pico_moca_230719_123506/spikeTime
# /braintree/data2/active/users/sgouldin/projects/mayo/monkeys/pico/intanproc/pico_mayo_230804_154202/spikeTime
# /braintree/data2/active/users/sgouldin/projects/mayo/monkeys/pico/intanproc/pico_mayo_230808_143723/spikeTime
# /braintree/data2/active/users/sgouldin/projects/mayo/monkeys/pico/intanproc/pico_mayo_230808_162123/spikeTime
# /braintree/data2/active/users/sgouldin/projects/mayo/monkeys/pico/intanproc/pico_mayo_230808_175311/spikeTime
# /braintree/data2/active/users/sgouldin/projects/mayo/monkeys/pico/intanproc/pico_mayo_230814_124244/spikeTime
# /braintree/data2/active/users/sgouldin/projects/mayo/monkeys/pico/intanproc/pico_mayo_230814_143555/spikeTime
# /braintree/data2/active/users/sgouldin/projects/mayo/monkeys/pico/intanproc/pico_mayo_230815_111611/spikeTime
# /braintree/data2/active/users/sgouldin/projects/mayo/monkeys/pico/intanproc/pico_mayo_230815_130758/spikeTime
# /braintree/data2/active/users/sgouldin/projects/mayo/monkeys/pico/intanproc/pico_mayo_230816_102642/spikeTime
# /braintree/data2/active/users/sgouldin/projects/mayo/monkeys/pico/intanproc/pico_mayo_230816_120828/spikeTime
# /braintree/data2/active/users/sgouldin/projects/mayo/monkeys/pico/intanproc/pico_mayo_230817_142520/spikeTime
# /braintree/data2/active/users/sgouldin/projects/mayo/monkeys/pico/intanproc/pico_mayo_230817_160705/spikeTime
# /braintree/data2/active/users/sgouldin/projects/mayo/monkeys/pico/intanproc/pico_mayo_230818_101245/spikeTime
# /braintree/data2/active/users/sgouldin/projects/mayo/monkeys/pico/intanproc/pico_mayo_230818_121533/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d0_v31/monkeys/pico/intanproc/pico_robustness_guy_d0_v31_230710_132817/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d1_v31/monkeys/pico/intanproc/pico_robustness_d1_v31_230711_143530/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d0_v32/monkeys/pico/intanproc/pico_robustness_guy_d0_v32_230712_140841/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d1_v32/monkeys/pico/intanproc/pico_robustness_guy_d1_v32_230713_143745/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d1_v33/monkeys/pico/intanproc/pico_robustness_d1_v33_230714_143634/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_chong_d0_v7/monkeys/pico/intanproc/pico_robustness_chong_d0_v7_230717_130030/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d0_v7_chong/monkeys/pico/intanproc/pico_robustness_guy_d0_v7_chong_230724_110235/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d1_v7_chong/monkeys/pico/intanproc/pico_robustness_guy_d1_v7_chong_230725_120111/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d1_v7_chong_dryrun/monkeys/pico/intanproc/pico_robustness_guy_d1_v7_chong_230721_124133/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d2_v7_chong/monkeys/pico/intanproc/pico_robustness_guy_d2_v7_chong_230726_141754/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d3_v7_chong/monkeys/pico/intanproc/pico_robustness_guy_d3_v7_chong_230727_155612/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d4_v7_chong/monkeys/pico/intanproc/pico_robustness_guy_d4_v7_chong_230728_170145/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d5_v7_chong/monkeys/pico/intanproc/pico_robustness_guy_d5_v7_chong_230729_155031/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d6_v7_chong/monkeys/pico/intanproc/pico_robustness_guy_d6_v7_chong_230730_140421/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d7_v7_chong/monkeys/pico/intanproc/pico_robustness_guy_d7_v7_chong_230731_110204/spikeTime
# /braintree/data2/active/users/sgouldin/projects/gratingsAdap_s1/monkeys/pico/intanproc/pico_gratingsAdap_s1_230801_151117/spikeTime
# /braintree/data2/active/users/sgouldin/projects/gratingsAdap_s2/monkeys/pico/intanproc/pico_gratingsAdap_s2_230801_155127/spikeTime
# /braintree/data2/active/users/sgouldin/projects/gratingsAdap_s3/monkeys/pico/intanproc/pico_gratingsAdap_s3_230801_163355/spikeTime
# /braintree/data2/active/users/sgouldin/projects/gratingsAdap_s4/monkeys/pico/intanproc/pico_gratingsAdap_s4_230801_174030/spikeTime
# /braintree/data2/active/users/sgouldin/projects/gratingsAdap_s5/monkeys/pico/intanproc/pico_gratingsAdap_s5_230801_144134/spikeTime
# /braintree/data2/active/users/sgouldin/projects/faceemovids/monkeys/pico/intanproc/pico_faceemovids_230908_100255/spikeTime
# /braintree/data2/active/users/sgouldin/projects/faceemovids/monkeys/pico/intanproc/pico_faceemovids_230908_111918/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d0_v34/monkeys/pico/intanproc/pico_robustness_d0_v34_230905_100312/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d1_v34/monkeys/pico/intanproc/pico_robustness_d1_v34_230906_094735/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d1_v34/monkeys/pico/intanproc/pico_robustness_d1_v34_230906_122650/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d0_v35/monkeys/pico/intanproc/pico_robustness_d0_v35_230912_105316/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d1_v35/monkeys/pico/intanproc/pico_robustness_d1_v35_230913_105856/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d1_v35/monkeys/pico/intanproc/pico_robustness_d1_v35_230913_130428/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d1_v36/monkeys/pico/intanproc/pico_robustness_d1_v36_230914_105649/spikeTime
# /braintree/data2/active/users/sgouldin/projects/robustness_guy_d0_v37/monkeys/pico/intanproc/pico_robustness_d0_v37_230919_095857/spikeTime
